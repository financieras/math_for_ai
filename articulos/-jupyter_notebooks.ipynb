# %% [markdown]
# <a href="https://colab.research.google.com/github/financieras/math_for_ai/blob/main/articulos/-jupyter_notebooks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Jupyter Notebooks

# %% [markdown]
# | **ID** | **RL** | **Title** | **Pub** | **Lang** |**Ready to Launch** | **Comments** |
# |:------:|:------:|:-----------|:--------:|:--------:|:-----------:|:-----------:|
# | 1 | | The Mystery of the 1 in Machine Learning | 1 | en | - | |
# | 2 | | Mastering Pandas GroupBy using Titanic (Part 1/2) | 1 | en | - | |
# | 3 | | Mastering Pandas GroupBy using Titanic (Part 2/2) | 1 | en | - | |
# | 4 | | Linear Algebra: Matrix Fundamentals | 1 | en | - | |
# | 5 | RL-MC | 02_linear_regression_from_scratch_with_python.ipynb| 0 | en | 99% | OLS Explained, 1º Artículo de Regresión Lineal|
# | 6 | RL-MC | 02_linear_regression_using_least_squares.ipynb | 0 | ES | | La primera parte está en el ID5 en inglés |
# | 7 | RL-MC| articulo1_regresion_lineal_por_minimos_cuadrados.ipynb | 0 | ES |||
# | 8 | RL-MC | articulo2_evaluando_regresion_lineal.ipynb | 0 | ES |||
# | 9 | | regresion_lineal_descenso_gradiente.ipynb | 0 | ES |||
# |10 | | regresion_logistica.ipynb | 0 | ES || | es Logistic Regression (Part 1/2), la parte 2 no está escrita |
