# %% [markdown]
# <a href="https://colab.research.google.com/github/financieras/math_for_ai/blob/main/articulos/-jupyter_notebooks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Jupyter Notebooks

# %% [markdown]
# | **ID** | **Title** | **Pub** | **Ready to Launch** | **Comments** |
# |:------:|:-----------|:--------:|:-----------:|:-----------:|
# | 1 | The Mystery of the 1 in Machine Learning | 1 | - | |
# | 2 | Mastering Pandas GroupBy using Titanic (Part 1/2) | 1 | - | |
# | 3 | Mastering Pandas GroupBy using Titanic (Part 2/2) | 1 | - | |
# | 4 | Linear Algebra: Matrix Fundamentals | 1 | - | |
# | 5 | 02_linear_regression_from_scratch_with_python.ipynb| 0 | 99% | OLS Explained, 1º Artículo de Regresión Lineal|
# | 6 | 02_linear_regression_using_least_squares.ipynb | 0 | | |
# | 7 | Regresion_Logistica_Como_la_Función_Sigmoide_Resuelve_la_Clasificacion_Binaria.ipynb | 0 |||
# | 8 | articulo1_regresion_lineal_descenso_gradiente.ipynb | 0 |||
# | 9 | articulo1_regresion_lineal_por_minimos_cuadrados.ipynb | 0 |||
# |10 | articulo2_evaluando_regresion_lineal.ipynb | 0 |||
# |11 | regresion_lineal_descenso_gradiente.ipynb | 0 |||
