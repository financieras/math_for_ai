# %% [markdown]
# <a href="https://colab.research.google.com/github/financieras/math_for_ai/blob/main/articulos/00_jupyter_notebooks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Jupyter Notebooks

# %% [markdown]
# | **ID** | **Titulo** | **Pub** | **Estado** |
# |:------:|:-----------|:--------:|:-----------:|
# | 1 | The Mystery of the 1 in Machine Learning | 1 | - |
# | 2 | Mastering Pandas GroupBy using Titanic (Part 1/2) | 1 | - |
# | 3 | Mastering Pandas GroupBy using Titanic (Part 2/2) | 1 | - |
# | 4 | Linear Algebra: Matrix Fundamentals | 1 | - |
